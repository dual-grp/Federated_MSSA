# %%
import matplotlib.pyplot as plt
import h5py
import numpy as np
from mpl_toolkits.axes_grid1.inset_locator import zoomed_inset_axes, mark_inset
from matplotlib.ticker import StrMethodFormatter
import os
plt.rcParams.update({'font.size': 14})

# %%
algorithms = ["FedMSSA: Missing val 0%",
              "FedMSSA: Missing val 20%",
              "FedMSSA: Missing val 40%",
              "FedMSSA: Missing val 60%",
              "FedMSSA: Missing val 80%"]
linestyles = ['-', '-', ':', ':',':', '--','-.']
markers = ["d","p","v","s","x","*","o"]
colors = [ 'tab:green', 'r', 'blue', 'tab:brown','tab:brown', 'm','slategray']
plt.figure(1,figsize=(10, 10))
x = [10, 43, 86, 172, 430]
xi = list(range(len(x)))
y= [[0.27, 0.28, 0.29, 0.31, 0.31], 
    [0.33, 0.34, 0.36, 0.38, 0.40], 
    [0.41, 0.43, 0.43, 0.45, 0.49], 
    [0.53, 0.52, 0.55, 0.58, 0.61],
    [0.65, 0.72, 0.73, 0.72, 0.7]]
for i in range(len(y)):
    plt.plot(xi, y[i], linestyle=linestyles[i], label=algorithms[i], linewidth  = 1, color=colors[i], marker = markers[i], markevery=0.05, markersize=5)
    plt.xticks(xi, x)
plt.ylabel('RSME')
plt.xlabel( "Number of users" )
plt.legend(loc='lower right', prop={'size': 9}, ncol=2)
plt.grid(True)
# plt.ylim([0.6,  2.9])
plt.title("Traffic 860")
# plt.savefig("Cifar_generalization_error.pdf", bbox_inches="tight",pad_inches = 0)
plt.show()

# %%
import numpy as np
# rmse = np.array(y)
# rmse_vs_misVal = rmse.T
rmse_vs_misVal = [[0.46, 0.63, 0.71, 2.02, 0.79],
                  [0.62, 0.63, 0.67, 0.71, 0.75],
                  [0.56, 0.57, 0.61, 0.65, 0.71],
                [0.27, 0.33, 0.41, 0.53, 0.65],
                [0.28, 0.34, 0.43, 0.52, 0.72],
                [0.29, 0.36, 0.43, 0.55, 0.73],
                [0.31, 0.38, 0.45, 0.58, 0.72],
                [0.31, 0.4, 0.49, 0.61, 0.7]]

# %%
algorithms = ["DeepAR",
            "SSA",
              "MSSA",
              "FedMSSA 10 clients - 86 TS/client",
              "FedMSSA 43 clients - 20 TS/client",
              "FedMSSA 86 clients -  10 TS/client",
              "FedMSSA 172 clients - 4 TS/client",
              "FedMSSA 430 clients - 2 TS/client"]
linestyles = ['-', '-', ':', ':',':', '--','-.','dashdot']
markers = ["d","p","v","s","x","*","o","*"]
colors = [ 'tab:green', 'r', 'blue', 'tab:brown','tab:brown', 'm','slategray', 'g']
plt.figure(1,figsize=(10, 10))
x = [0, 20, 40, 60, 80]
xi = list(range(len(x)))
y = rmse_vs_misVal
for i in range(len(y)):
    plt.plot(xi, y[i], linestyle=linestyles[i], label=algorithms[i], linewidth  = 1, color=colors[i], marker = markers[i], markevery=0.05, markersize=5)
    plt.xticks(xi, x)
plt.ylabel('RSME')
plt.xlabel( "Missing percentage" )
plt.legend(loc='upper left', prop={'size': 9}, ncol=2)
plt.grid(True)
# plt.ylim([0.6,  2.9])
plt.title("Traffic 860")
# plt.savefig("Cifar_generalization_error.pdf", bbox_inches="tight",pad_inches = 0)
plt.show()
